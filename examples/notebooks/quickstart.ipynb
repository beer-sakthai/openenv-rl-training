# %% [markdown]
# <a href="https://colab.research.google.com/github/beer-sakthai/openenv-rl-training/blob/main/examples/notebooks/quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup and Imports

# %%
# !pip install -Uq trackio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 59.3 MB/s eta 0:00:00

# %%
import trackio

# %% [markdown]
# ## Initialize a project
#
# We will initialize a project, which will hold a collection of runs. You can consider runs to be each individual experiment.
#
# > **Note:** You need to have your Hugging Face token accessible (e.g., stored in your environment as `HF_TOKEN`).
# > You can generate or copy your token from [https://huggingface.co/settings/tokens](https://huggingface.co/settings/tokens).

# %%
experiment_1 = trackio.init(
    project="quickstart", name="experiment_1", space_id="quickstart-trackio"
)
# Out:
# * Trackio project initialized: quickstart
# * Trackio metrics will be synced to Hugging Face Bucket: https://huggingface.co/buckets/Nanthasit/quickstart-trackio-bucket
# * Creating new space: https://huggingface.co/spaces/Nanthasit/quickstart-trackio
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: trackio.init() could not prepare Space 'Nanthasit/quickstart-trackio': Failed to create Space: Client error '402 Payment Required' for url 'https://huggingface.co/api/repos/create' (Request ID: Root=1-6a86989b-253b333f4b7c42727f328132;ddae52de-cfec-477c-80be-845361e74356)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# Static Spaces are free for everyone, but hosting Gradio and Docker Spaces on free cpu-basic requires a PRO subscription. Subscribe at https://huggingface.co/pro. Logging will continue in local fallback mode until the Space is reachable.
#   warnings.warn(message, *args, **kwargs)
# * psutil detected, enabling automatic CPU/system metrics logging
# * Created new run: experiment_1
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: trackio.init() could not create a remote client for Space 'Nanthasit/quickstart-trackio': Could not connect to Space 'Nanthasit/quickstart-trackio'. Is it running?
# 404 Client Error. (Request ID: Root=1-6a86989b-418912e3028554b65c5871bf;596aa9ff-ae91-4c89-9ea5-feabe377f8c9)
#
# Repository Not Found for url: https://huggingface.co/api/spaces/Nanthasit/quickstart-trackio.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.
# For more details, see https://huggingface.co/docs/huggingface_hub/authentication. Continuing with local fallback metadata lookups.
#   warnings.warn(message, *args, **kwargs)

# %% [markdown]
# After we have initialized a run for a project, it is time we log some metrics.

# %%
for idx in range(100):
    experiment_1.log(
        {
            "idx": idx,
            "loss": 100 - idx,
        }
    )

# %% [markdown]
# After uploading the metrics let's finish this experiment.

# %%
experiment_1.finish()
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: trackio could not upload buffered logs to Bucket 'Nanthasit/quickstart-trackio-bucket': Network error: Request error: HTTP status client error (404 Not Found), domain: https://huggingface.co/api/buckets/Nanthasit/quickstart-trackio-bucket/xet-write-token. It will retry later if possible.
#   warnings.warn(message, *args, **kwargs)
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: trackio could not upload buffered logs to Bucket 'Nanthasit/quickstart-trackio-bucket': Previous task error: Network error: Request error: HTTP status client error (404 Not Found), domain: https://huggingface.co/api/buckets/Nanthasit/quickstart-trackio-bucket/xet-write-token. It will retry later if possible.
#   warnings.warn(message, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: * Some logs could not be sent to the remote server (it may still be starting up). They have been saved locally and will be sent automatically next time you call: trackio.init(project="quickstart", space_id="Nanthasit/quickstart-trackio")
#   warnings.warn(message, *args, **kwargs)

# %% [markdown]
# ## Adding configuration
#
# Each experiment we run has different configurations. Here we will tag configs to runs.
#
# You can also use the `config` attribute when you run the experiment.

# %%
config = {
    "lr": 0.01,
}
experiment_2 = trackio.init(
    project="quickstart",
    name="experiment_2",
    space_id="quickstart-trackio",
    config=config,
)
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# * Created new run: experiment_2
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: trackio.init() could not create a remote client for Space 'Nanthasit/quickstart-trackio': Could not connect to Space 'Nanthasit/quickstart-trackio'. Is it running?
# 404 Client Error. (Request ID: Root=1-6a86989d-7d6dbb7e0c5a6fb90440c0a4;28b0f340-1297-4df3-bf69-101358315caf)
#
# Repository Not Found for url: https://huggingface.co/api/spaces/Nanthasit/quickstart-trackio.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.
# For more details, see https://huggingface.co/docs/huggingface_hub/authentication. Continuing with local fallback metadata lookups.
#   warnings.warn(message, *args, **kwargs)

# %%
experiment_2.config
# Out:
# {'lr': 0.01,
#  '_Username': 'Nanthasit',
#  '_Created': '2026-08-20T06:03:09.322379+00:00',
#  '_Group': None}

# %%
for idx in range(100):
    experiment_2.log(
        {
            "idx": idx,
            "loss": 100 - idx * experiment_2.config["lr"],  # We use the config here.
        }
    )

# %%
experiment_2.finish()
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B

# %% [markdown]
# ## Wrapping it all together

# %%
import random

num_experiments = 5
epochs = 100

for idx in range(num_experiments):
    experiment = trackio.init(
        project="quickstart", name=f"experiment_{idx}", space_id="quickstart-trackio"
    )

    for epoch in range(epochs):
        train_loss = random.uniform(0.2, 1.0)
        train_acc = random.uniform(0.6, 0.95)

        val_loss = train_loss - random.uniform(0.01, 0.1)
        val_acc = train_acc + random.uniform(0.01, 0.05)

        experiment.log(
            {
                "epoch": epoch,
                "train_loss": train_loss,
                "train_accuracy": train_acc,
                "val_loss": val_loss,
                "val_accuracy": val_acc,
            }
        )

    experiment.finish()
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# * Created new run: experiment_0
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: trackio.init() could not create a remote client for Space 'Nanthasit/quickstart-trackio': Could not connect to Space 'Nanthasit/quickstart-trackio'. Is it running?
# 404 Client Error. (Request ID: Root=1-6a86989d-2cdf2e1934b39edc3a8ff34b;05eab7bc-6b0a-4cd3-9c92-aecf950f4e7d)
#
# Repository Not Found for url: https://huggingface.co/api/spaces/Nanthasit/quickstart-trackio.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.
# For more details, see https://huggingface.co/docs/huggingface_hub/authentication. Continuing with local fallback metadata lookups.
#   warnings.warn(message, *args, **kwargs)
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# * Created new run: experiment_1
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: trackio.init() could not create a remote client for Space 'Nanthasit/quickstart-trackio': Could not connect to Space 'Nanthasit/quickstart-trackio'. Is it running?
# 404 Client Error. (Request ID: Root=1-6a86989e-003c31b401c486be737ab9e3;f775d679-cd8b-496a-b5b2-6bb8a4fcbc02)
#
# Repository Not Found for url: https://huggingface.co/api/spaces/Nanthasit/quickstart-trackio.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.
# For more details, see https://huggingface.co/docs/huggingface_hub/authentication. Continuing with local fallback metadata lookups.
#   warnings.warn(message, *args, **kwargs)
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# * Created new run: experiment_2
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: trackio.init() could not create a remote client for Space 'Nanthasit/quickstart-trackio': Could not connect to Space 'Nanthasit/quickstart-trackio'. Is it running?
# 404 Client Error. (Request ID: Root=1-6a86989f-37e717ab7c69dab461fe46e1;be7ee296-ca19-41a5-9447-e6877b0f6de0)
#
# Repository Not Found for url: https://huggingface.co/api/spaces/Nanthasit/quickstart-trackio.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.
# For more details, see https://huggingface.co/docs/huggingface_hub/authentication. Continuing with local fallback metadata lookups.
#   warnings.warn(message, *args, **kwargs)
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# * Created new run: experiment_3
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: trackio.init() could not create a remote client for Space 'Nanthasit/quickstart-trackio': Could not connect to Space 'Nanthasit/quickstart-trackio'. Is it running?
# 404 Client Error. (Request ID: Root=1-6a86989f-0b1ea9d119e186090572e8e5;4d4a175a-9719-4a73-82e4-7558cb2df387)
#
# Repository Not Found for url: https://huggingface.co/api/spaces/Nanthasit/quickstart-trackio.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.
# For more details, see https://huggingface.co/docs/huggingface_hub/authentication. Continuing with local fallback metadata lookups.
#   warnings.warn(message, *args, **kwargs)
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# /usr/local/lib/python3.12/dist-packages/trackio/utils.py:27: UserWarning: trackio.init() could not create a remote client for Space 'Nanthasit/quickstart-trackio': Could not connect to Space 'Nanthasit/quickstart-trackio'. Is it running?
# 404 Client Error. (Request ID: Root=1-6a8698a0-7af9edae0975bf3d75a783ab;2135d929-0e0b-4659-bdff-f338b037380e)
#
# Repository Not Found for url: https://huggingface.co/api/spaces/Nanthasit/quickstart-trackio.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.
# For more details, see https://huggingface.co/docs/huggingface_hub/authentication. Continuing with local fallback metadata lookups.
#   warnings.warn(message, *args, **kwargs)
# * Created new run: experiment_4
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B

# %% [markdown]
# ##
